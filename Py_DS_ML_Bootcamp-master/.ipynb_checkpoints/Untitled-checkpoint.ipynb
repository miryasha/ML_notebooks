# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file into a pandas DataFrame
df = pd.read_csv('./bull.csv')

df.head()
# Out:
#    id strategy_name  trade_duration market_name symbol market_category  \
# 0   1           ttm               1       stock    spy    sp_100_daily
# 1   2           ttm               1       stock    spy    sp_100_daily
# 2   3           ttm               1       stock    spy    sp_100_daily
# 3   4           ttm               1       stock    spy    sp_100_daily
# 4   5           ttm               1       stock    spy    sp_100_daily
#
#   signal_direction  signal_opening_price  signal_high_price  signal_low_price  \
# 0             Bear                237.18             237.24            236.19
# 1             Bear                235.80             236.03            233.91
# 2             Bear                242.90             244.19            242.20
# 3             Bear                268.81             269.06            265.61
# 4             Bear                283.71             283.82            280.38
#
#    ...     tp_date  tp_date_day  tp_date_num_day tp_date_month  \
# ...

# %%
# Select the two columns you want to analyze
column1 = df['signal_date_num_day']
column2 = df['tp_date_num_day']

# Calculate the correlation between the two columns
correlation = column1.corr(column2)

# Print the correlation
print("The correlation between column1 and column2 is:", correlation)

# Plot a scatter plot to visualize the correlation
plt.scatter(column1, column2)
plt.xlabel('signal_date_num_day')
plt.ylabel('tp_date_num_day')
plt.title('Scatter plot of Column 1 and Column 2')
plt.show()
# Out:
# The correlation between column1 and column2 is: 0.02793880662740353
